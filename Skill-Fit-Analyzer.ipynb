# %%
# ---DATA ANALYST JOB ELIGIBLITY CHECKER---

# %%
print("---DATA ANALYST ELIGIBLITY CHECKER---")
# Out:
# ---DATA ANALYST ELIGIBLITY CHECKER---

# %%
print("Answer a few questions to see if you are ready to apply!\n")
# Out:
# Answer a few questions to see if you are ready to apply!

# %%
name = input ("Enter your name")
python_score = int(input("enter python score (1-10):"))
projects = int(input("How many projects have you made?:"))
# Out:
# Enter your name Amit
# enter python score (1-10): 8
# How many projects have you made?: 5

# %%
if python_score >= 7 and projects >=2:
    print(f"\n congratulations {name}!You are ready for the job.")
elif python_score >= 5 or projects >= 1:
    print(f"\n {name},you are on the right track! Just need a little more practice.")
else:
    print(f"\n keep learning, {name}! Start with phython basics first.")
# Out:
#  congratulations Amit!You are ready for the job.
